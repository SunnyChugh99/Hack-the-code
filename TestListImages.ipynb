# %%
# !pip install snowflake-core
# Out:
# Collecting snowflake-core
#   Downloading https://files.pythonhosted.org/packages/6d/23/3da7c3903f7d491ae6a4b5b613323815f0a955f5526682fc17392e892617/snowflake_core-0.10.0-py3-none-any.whl (625kB)
#      |████████████████████████████████| 634kB 10.3MB/s eta 0:00:01
# Collecting pydantic>=2
#   Downloading https://files.pythonhosted.org/packages/1f/fa/b7f815b8c9ad021c07f88875b601222ef5e70619391ade4a49234d12d278/pydantic-2.8.2-py3-none-any.whl (423kB)
#      |████████████████████████████████| 430kB 82.8MB/s eta 0:00:01
# Requirement already satisfied: snowflake-snowpark-python<2.0.0,>=1.5.0 in /opt/conda/lib/python3.9/site-packages (from snowflake-core) (1.20.0)
# Requirement already satisfied: urllib3 in /opt/conda/lib/python3.9/site-packages (from snowflake-core) (1.26.19)
# Requirement already satisfied: requests in /opt/conda/lib/python3.9/site-packages (from snowflake-core) (2.32.2)
# Collecting atpublic>=4
#   Downloading https://files.pythonhosted.org/packages/5e/5e/3613e5aa17ac07a69e89a5f47706f5719035f386eb024d6680483926b034/atpublic-4.1.0-py3-none-any.whl
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/conda/lib/python3.9/site-packages (from snowflake-core) (2.9.0.post0)
# Collecting pydantic-core==2.20.1
#   Downloading https://files.pythonhosted.org/packages/9b/f1/a006955715be98093d092aa025f604c7c00721e83fe04bf467c49f31a685/pydantic_core-2.20.1-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.1MB)
#      |████████████████████████████████| 2.1MB 84.0MB/s eta 0:00:01
# Requirement already satisfied: typing-extensions>=4.6.1; python_version < "3.13" in /opt/conda/lib/python3.9/site-packages (from pydantic>=2->snowflake-core) (4.12.2)
# Collecting annotated-types>=0.4.0
#   Downloading https://files.pythonhosted.org/packages/78/b6/6307fbef88d9b5ee7421e68d78a9f162e0da4900bc5f5793f6d3d0e34fb8/annotated_types-0.7.0-py3-none-any.whl
# Requirement already satisfied: snowflake-connector-python<4.0.0,>=3.10.0 in /opt/conda/lib/python3.9/site-packages (from snowflake-snowpark-python<2.0.0,>=1.5.0->snowflake-core) (3.11.0)
# Requirement already satisfied: cloudpickle!=2.1.0,!=2.2.0,<=2.2.1,>=1.6.0; python_version < "3.11" in /opt/conda/lib/python3.9/site-packages (from snowflake-snowpark-python<2.0.0,>=1.5.0->snowflake-core) (2.2.1)
# Requirement already satisfied: setuptools>=40.6.0 in /opt/conda/lib/python3.9/site-packages (from snowflake-snowpark-python<2.0.0,>=1.5.0->snowflake-core) (65.6.3)
# Requirement already satisfied: wheel in /opt/conda/lib/python3.9/site-packages (from snowflake-snowpark-python<2.0.0,>=1.5.0->snowflake-core) (0.37.1)
# Requirement already satisfied: pyyaml in /opt/conda/lib/python3.9/site-packages (from snowflake-snowpark-python<2.0.0,>=1.5.0->snowflake-core) (6.0.1)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.9/site-packages (from requests->snowflake-core) (2024.6.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.9/site-packages (from requests->snowflake-core) (3.7)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.9/site-packages (from requests->snowflake-core) (2.0.4)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.9/site-packages (from python-dateutil>=2.8.2->snowflake-core) (1.16.0)
# Requirement already satisfied: tomlkit in /opt/conda/lib/python3.9/site-packages (from snowflake-connector-python<4.0.0,>=3.10.0->snowflake-snowpark-python<2.0.0,>=1.5.0->snowflake-core) (0.13.0)
# Requirement already satisfied: cryptography<43.0.0,>=3.1.0 in /opt/conda/lib/python3.9/site-packages (from snowflake-connector-python<4.0.0,>=3.10.0->snowflake-snowpark-python<2.0.0,>=1.5.0->snowflake-core) (42.0.5)
# Requirement already satisfied: pyOpenSSL<25.0.0,>=16.2.0 in /opt/conda/lib/python3.9/site-packages (from snowflake-connector-python<4.0.0,>=3.10.0->snowflake-snowpark-python<2.0.0,>=1.5.0->snowflake-core) (24.0.0)
# Requirement already satisfied: sortedcontainers>=2.4.0 in /opt/conda/lib/python3.9/site-packages (from snowflake-connector-python<4.0.0,>=3.10.0->snowflake-snowpark-python<2.0.0,>=1.5.0->snowflake-core) (2.4.0)
# Requirement already satisfied: platformdirs<5.0.0,>=2.6.0 in /opt/conda/lib/python3.9/site-packages (from snowflake-connector-python<4.0.0,>=3.10.0->snowflake-snowpark-python<2.0.0,>=1.5.0->snowflake-core) (4.2.2)
# Requirement already satisfied: cffi<2.0.0,>=1.9 in /opt/conda/lib/python3.9/site-packages (from snowflake-connector-python<4.0.0,>=3.10.0->snowflake-snowpark-python<2.0.0,>=1.5.0->snowflake-core) (1.16.0)
# Requirement already satisfied: packaging in /opt/conda/lib/python3.9/site-packages (from snowflake-connector-python<4.0.0,>=3.10.0->snowflake-snowpark-python<2.0.0,>=1.5.0->snowflake-core) (23.2)
# Requirement already satisfied: filelock<4,>=3.5 in /opt/conda/lib/python3.9/site-packages (from snowflake-connector-python<4.0.0,>=3.10.0->snowflake-snowpark-python<2.0.0,>=1.5.0->snowflake-core) (3.15.4)
# Requirement already satisfied: asn1crypto<2.0.0,>0.24.0 in /opt/conda/lib/python3.9/site-packages (from snowflake-connector-python<4.0.0,>=3.10.0->snowflake-snowpark-python<2.0.0,>=1.5.0->snowflake-core) (1.5.1)
# Requirement already satisfied: pyjwt<3.0.0 in /opt/conda/lib/python3.9/site-packages (from snowflake-connector-python<4.0.0,>=3.10.0->snowflake-snowpark-python<2.0.0,>=1.5.0->snowflake-core) (2.8.0)
# Requirement already satisfied: pytz in /opt/conda/lib/python3.9/site-packages (from snowflake-connector-python<4.0.0,>=3.10.0->snowflake-snowpark-python<2.0.0,>=1.5.0->snowflake-core) (2024.1)
# Requirement already satisfied: pycparser in /opt/conda/lib/python3.9/site-packages (from cffi<2.0.0,>=1.9->snowflake-connector-python<4.0.0,>=3.10.0->snowflake-snowpark-python<2.0.0,>=1.5.0->snowflake-core) (2.21)
# Installing collected packages: pydantic-core, annotated-types, pydantic, atpublic, snowflake-core
# Successfully installed annotated-types-0.7.0 atpublic-4.1.0 pydantic-2.8.2 pydantic-core-2.20.1 snowflake-core-0.10.0
# WARNING: You are using pip version 19.3.1; however, version 24.1.2 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.

# %%
from snowflake.core import Root

# %%
from snowflake.snowpark.session import Session

# %%
connection_params = {'user': 'SAURABHKULKARNI', 'password': 'Epsilon0*', 'account': 'fya62509.us-east-1', 'role': 'SAURABHKULKARNI', 'warehouse': 'FOSFOR_INSIGHT_WH', 'database': 'INSIGHT_DESIGNER_SPCS', 'schema': 'INSIGHT_SPCS_SCHEMA'}

# %%
new_session = Session.builder.configs(connection_params).create()
# Out:
# ---------------------------------------------------------------------------
# DatabaseError                             Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 new_session = Session.builder.configs(connection_params).create()
#
# File /opt/conda/lib/python3.9/site-packages/snowflake/snowpark/session.py:412, in Session.SessionBuilder.create(self)
#     410     _add_session(session)
#     411 else:
# --> 412     session = self._create_internal(self._options.get("connection"))
#     414 if self._app_name:
#     415     if self._format_json:
#
# File /opt/conda/lib/python3.9/site-packages/snowflake/snowpark/session.py:454, in Session.SessionBuilder._create_internal(self, conn)
#     451 if "paramstyle" not in self._options:
#     452     self._options["paramstyle"] = "qmark"
#     453 new_session = Session(
# --> 454     ServerConnection({}, conn) if conn else ServerConnection(self._options),
#     455     self._options,
#     456 )
#     458 if "password" in self._options:
#     459     self._options["password"] = None
#
# File /opt/conda/lib/python3.9/site-packages/snowflake/snowpark/_internal/server_connection.py:157, in ServerConnection.__init__(self, options, conn)
#     155 self._lower_case_parameters = {k.lower(): v for k, v in options.items()}
#     156 self._add_application_parameters()
# --> 157 self._conn = conn if conn else connect(**self._lower_case_parameters)
#     158 if "password" in self._lower_case_parameters:
#     159     self._lower_case_parameters["password"] = None
#
# File /opt/conda/lib/python3.9/site-packages/snowflake/connector/__init__.py:55, in Connect(**kwargs)
#      53 @wraps(SnowflakeConnection.__init__)
#      54 def Connect(**kwargs) -> SnowflakeConnection:
# ---> 55     return SnowflakeConnection(**kwargs)
#
# File /opt/conda/lib/python3.9/site-packages/snowflake/connector/connection.py:451, in SnowflakeConnection.__init__(self, connection_name, connections_file_path, **kwargs)
#     449     kwargs = _get_default_connection_params()
#     450 self.__set_error_attributes()
# --> 451 self.connect(**kwargs)
#     452 self._telemetry = TelemetryClient(self._rest)
#     453 self.expired = False
#
# File /opt/conda/lib/python3.9/site-packages/snowflake/connector/connection.py:756, in SnowflakeConnection.connect(self, **kwargs)
#     754             raise Exception(str(exceptions_dict))
#     755 else:
# --> 756     self.__open_connection()
#
# File /opt/conda/lib/python3.9/site-packages/snowflake/connector/connection.py:1084, in SnowflakeConnection.__open_connection(self)
#    1076 else:
#    1077     # okta URL, e.g., https://<account>.okta.com/
#    1078     self.auth_class = AuthByOkta(
#    1079         application=self.application,
#    1080         timeout=self._login_timeout,
#    1081         backoff_generator=self._backoff_generator,
#    1082     )
# -> 1084 self.authenticate_with_retry(self.auth_class)
#    1086 self._password = None  # ensure password won't persist
#    1087 self.auth_class.reset_secrets()
#
# File /opt/conda/lib/python3.9/site-packages/snowflake/connector/connection.py:1364, in SnowflakeConnection.authenticate_with_retry(self, auth_instance)
#    1361 def authenticate_with_retry(self, auth_instance) -> None:
#    1362     # make some changes if needed before real __authenticate
#    1363     try:
# -> 1364         self._authenticate(auth_instance)
#    1365     except ReauthenticationRequest as ex:
#    1366         # cached id_token expiration error, we have cleaned id_token and try to authenticate again
#    1367         logger.debug("ID token expired. Reauthenticating...: %s", ex)
#
# File /opt/conda/lib/python3.9/site-packages/snowflake/connector/connection.py:1392, in SnowflakeConnection._authenticate(self, auth_instance)
#    1390 auth_instance._retry_ctx.set_start_time()
#    1391 try:
# -> 1392     auth.authenticate(
#    1393         auth_instance=auth_instance,
#    1394         account=self.account,
#    1395         user=self.user,
#    1396         database=self.database,
#    1397         schema=self.schema,
#    1398         warehouse=self.warehouse,
#    1399         role=self.role,
#    1400         passcode=self._passcode,
#    1401         passcode_in_password=self._passcode_in_password,
#    1402         mfa_callback=self._mfa_callback,
#    1403         password_callback=self._password_callback,
#    1404         session_parameters=self._session_parameters,
#    1405     )
#    1406 except OperationalError as e:
#    1407     logger.debug(
#    1408         "Operational Error raised at authentication"
#    1409         f"for authenticator: {type(auth_instance).__name__}"
#    1410     )
#
# File /opt/conda/lib/python3.9/site-packages/snowflake/connector/auth/_auth.py:401, in Auth.authenticate(self, auth_instance, account, user, database, schema, warehouse, role, passcode, passcode_in_password, mfa_callback, password_callback, session_parameters, timeout)
#     399     if isinstance(auth_instance, AuthByUsrPwdMfa):
#     400         delete_temporary_credential(self._rest._host, user, MFA_TOKEN)
# --> 401     Error.errorhandler_wrapper(
#     402         self._rest._connection,
#     403         None,
#     404         DatabaseError,
#     405         {
#     406             "msg": (
#     407                 "Failed to connect to DB: {host}:{port}. " "{message}"
#     408             ).format(
#     409                 host=self._rest._host,
#     410                 port=self._rest._port,
#     411                 message=ret["message"],
#     412             ),
#     413             "errno": ER_FAILED_TO_CONNECT_TO_DB,
#     414             "sqlstate": SQLSTATE_CONNECTION_WAS_NOT_ESTABLISHED,
#     415         },
#     416     )
#     417 else:
#     418     logger.debug(
#     419         "token = %s",
#     420         (
#    (...)
#     424         ),
#     425     )
#
# File /opt/conda/lib/python3.9/site-packages/snowflake/connector/errors.py:290, in Error.errorhandler_wrapper(connection, cursor, error_class, error_value)
#     267 @staticmethod
#     268 def errorhandler_wrapper(
#     269     connection: SnowflakeConnection | None,
#    (...)
#     272     error_value: dict[str, Any],
#     273 ) -> None:
#     274     """Error handler wrapper that calls the errorhandler method.
#     275
#     276     Args:
#    (...)
#     287         exception to the first handler in that order.
#     288     """
# --> 290     handed_over = Error.hand_to_other_handler(
#     291         connection,
#     292         cursor,
#     293         error_class,
#     294         error_value,
#     295     )
#     296     if not handed_over:
#     297         raise Error.errorhandler_make_exception(
#     298             error_class,
#     299             error_value,
#     300         )
#
# File /opt/conda/lib/python3.9/site-packages/snowflake/connector/errors.py:348, in Error.hand_to_other_handler(connection, cursor, error_class, error_value)
#     346     return True
#     347 elif connection is not None:
# --> 348     connection.errorhandler(connection, cursor, error_class, error_value)
#     349     return True
#     350 return False
#
# File /opt/conda/lib/python3.9/site-packages/snowflake/connector/errors.py:221, in Error.default_errorhandler(connection, cursor, error_class, error_value)
#     219 errno = error_value.get("errno")
#     220 done_format_msg = error_value.get("done_format_msg")
# --> 221 raise error_class(
#     222     msg=error_value.get("msg"),
#     223     errno=None if errno is None else int(errno),
#     224     sqlstate=error_value.get("sqlstate"),
#     225     sfqid=error_value.get("sfqid"),
#     226     query=error_value.get("query"),
#     227     done_format_msg=(
#     228         None if done_format_msg is None else bool(done_format_msg)
#     229     ),
#     230     connection=connection,
#     231     cursor=cursor,
#     232 )
#
# DatabaseError: 250001 (08001): Failed to connect to DB: fya62509.us-east-1.snowflakecomputing.com:443. Error connecting to Snowflake via Snowpark Container Services. Please use OAuth when connecting to Snowflake. For more information please refer to https://docs.snowflake.com/en/developer-guide/snowpark-container-services/additional-considerations-services-jobs#connecting-to-snowflake-from-inside-a-container.

# %%
root = Root(new_session)

# %%
# from snowflake.core.image_repository import ImageRepository
# new_image_repo = ImageRepository(name="INSIGHT_SPCS_REPOSITORY",repository_url="zqiseam-ltifosforscsaws.registry.snowflakecomputing.com/insight_designer_spcs/insight_spcs_schema/insight_spcs_repository")

# %%
image_repositories_coll = root.databases["INSIGHT_DESIGNER_SPCS"].schemas["INSIGHT_SPCS_SCHEMA"].image_repositories

# %%
# Out:
# <snowflake.core.image_repository._image_repository.ImageRepositoryCollection object at 0x7fd204dbd070>

# %%
from snowflake.core.image_repository import ImageRepositoryResource
new_image_repo_resource = ImageRepositoryResource(name="INSIGHT_SPCS_REPOSITORY", collection=image_repositories_coll)

# %%
print(new_image_repo_resource.list_images_in_repository())
# Out:
# ---------------------------------------------------------------------------
# APIError                                  Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 print(new_image_repo_resource.list_images_in_repository())
#
# File /opt/conda/lib/python3.9/site-packages/snowflake/core/_internal/telemetry.py:111, in api_telemetry.<locals>.wrap(self, *args, **kwargs)
#     106     api.api_client  # noqa: B018
#     107 telemetry_client.send_api_telemetry(
#     108     class_name=self.__class__.__name__,
#     109     func_name=func.__name__,
#     110 )
# --> 111 r = func(self, *args, **kwargs)
#     112 return r
#
# File /opt/conda/lib/python3.9/site-packages/snowflake/core/image_repository/_image_repository.py:112, in ImageRepositoryResource.list_images_in_repository(self)
#     109 @api_telemetry
#     110 def list_images_in_repository(self) -> Iterator[str]:
#     111     """List images in the image repository from Snowflake."""
# --> 112     images = self.collection._api.list_images_in_repository(
#     113         self.database.name, self.schema.name, self.name, async_req=False
#     114     )
#     115     return iter([]) if images.images is None else iter(images.images)
#
# File /opt/conda/lib/python3.9/site-packages/pydantic/validate_call_decorator.py:60, in validate_call.<locals>.validate.<locals>.wrapper_function(*args, **kwargs)
#      58 @functools.wraps(function)
#      59 def wrapper_function(*args, **kwargs):
# ---> 60     return validate_call_wrapper(*args, **kwargs)
#
# File /opt/conda/lib/python3.9/site-packages/pydantic/_internal/_validate_call.py:96, in ValidateCallWrapper.__call__(self, *args, **kwargs)
#      95 def __call__(self, *args: Any, **kwargs: Any) -> Any:
# ---> 96     res = self.__pydantic_validator__.validate_python(pydantic_core.ArgsKwargs(args, kwargs))
#      97     if self.__return_pydantic_validator__:
#      98         return self.__return_pydantic_validator__(res)
#
# File /opt/conda/lib/python3.9/site-packages/snowflake/core/image_repository/_generated/api/image_repository_api.py:749, in ImageRepositoryApi.list_images_in_repository(self, database, var_schema, name, **kwargs)
#     717 """List images in the image repository.  # noqa: E501
#     718
#     719
#    (...)
#     746 :rtype: ListImagesInRepository200Response
#     747 """
#     748 kwargs['_return_http_data_only'] = True
# --> 749 return self.list_images_in_repository_with_http_info(
#     750     database, var_schema, name, **kwargs)
#
# File /opt/conda/lib/python3.9/site-packages/pydantic/validate_call_decorator.py:60, in validate_call.<locals>.validate.<locals>.wrapper_function(*args, **kwargs)
#      58 @functools.wraps(function)
#      59 def wrapper_function(*args, **kwargs):
# ---> 60     return validate_call_wrapper(*args, **kwargs)
#
# File /opt/conda/lib/python3.9/site-packages/pydantic/_internal/_validate_call.py:96, in ValidateCallWrapper.__call__(self, *args, **kwargs)
#      95 def __call__(self, *args: Any, **kwargs: Any) -> Any:
# ---> 96     res = self.__pydantic_validator__.validate_python(pydantic_core.ArgsKwargs(args, kwargs))
#      97     if self.__return_pydantic_validator__:
#      98         return self.__return_pydantic_validator__(res)
#
# File /opt/conda/lib/python3.9/site-packages/snowflake/core/image_repository/_generated/api/image_repository_api.py:873, in ImageRepositoryApi.list_images_in_repository_with_http_info(self, database, var_schema, name, **kwargs)
#     859 _auth_settings = []  # noqa: E501
#     861 _response_types_map = {
#     862     '200': "ListImagesInRepository200Response",
#     863     '400': "ErrorResponse",
#    (...)
#     870     '504': "ErrorResponse",
#     871 }
# --> 873 return self.api_client.call_api(
#     874     self._root,
#     875     '/api/v2/databases/{database}/schemas/{schema}/image-repositories/{name}/images',
#     876     'GET',
#     877     _path_params,
#     878     _query_params,
#     879     _header_params,
#     880     body=_body_params,
#     881     post_params=_form_params,
#     882     files=_files,
#     883     response_types_map=_response_types_map,
#     884     auth_settings=_auth_settings,
#     885     async_req=_params.get('async_req'),
#     886     _return_http_data_only=_params.get(
#     887         '_return_http_data_only'),  # noqa: E501
#     888     _preload_content=_params.get('_preload_content', True),
#     889     _request_timeout=_params.get('_request_timeout'),
#     890     collection_formats=_collection_formats,
#     891     _request_auth=_params.get('_request_auth'))
#
# File /opt/conda/lib/python3.9/site-packages/snowflake/core/image_repository/_generated/api_client.py:509, in ApiClient.call_api(self, root, resource_path, method, path_params, query_params, header_params, body, post_params, files, response_types_map, auth_settings, async_req, _return_http_data_only, collection_formats, _preload_content, _request_timeout, _host, _request_auth)
#     468 """Makes the HTTP request (synchronous) and returns deserialized data.
#     469
#     470 To make an async_req request, set the async_req parameter.
#    (...)
#     506     then the method will return the response directly.
#     507 """
#     508 if not async_req:
# --> 509     return self.__call_api(
#     510         root,
#     511         resource_path,
#     512         method,
#     513         path_params,
#     514         query_params,
#     515         header_params,
#     516         body,
#     517         post_params,
#     518         files,
#     519         response_types_map,
#     520         auth_settings,
#     521         _return_http_data_only,
#     522         collection_formats,
#     523         _preload_content,
#     524         _request_timeout,
#     525         _host,
#     526         _request_auth,
#     527     )
#     529 return self.pool.apply_async(self.__call_api, (
#     530     root,
#     531     resource_path,
#    (...)
#     546     _request_auth,
#     547 ))
#
# File /opt/conda/lib/python3.9/site-packages/snowflake/core/image_repository/_generated/api_client.py:268, in ApiClient.__call_api(self, root, resource_path, method, path_params, query_params, header_params, body, post_params, files, response_types_map, auth_settings, _return_http_data_only, collection_formats, _preload_content, _request_timeout, _host, _request_auth)
#     266     if e.body:
#     267         e.body = e.body.decode('utf-8')
# --> 268     raise e
#     270 self.last_response = response_data
#     272 return_data = response_data
#
# File /opt/conda/lib/python3.9/site-packages/snowflake/core/image_repository/_generated/api_client.py:255, in ApiClient.__call_api(self, root, resource_path, method, path_params, query_params, header_params, body, post_params, files, response_types_map, auth_settings, _return_http_data_only, collection_formats, _preload_content, _request_timeout, _host, _request_auth)
#     251     url += "?" + url_query
#     253 try:
#     254     # perform request and return response, maybe with retry
# --> 255     response_data = self.request_with_retry(
#     256         root,
#     257         method,
#     258         url,
#     259         query_params=query_params,
#     260         headers=header_params,
#     261         post_params=post_params,
#     262         body=body,
#     263         _preload_content=_preload_content,
#     264         _request_timeout=_request_timeout)
#     265 except APIError as e:
#     266     if e.body:
#
# File /opt/conda/lib/python3.9/site-packages/snowflake/core/image_repository/_generated/api_client.py:563, in ApiClient.request_with_retry(self, root, method, url, query_params, headers, post_params, body, _preload_content, _request_timeout)
#     559 """
#     560     Response time by default one hour
#     561 """
#     562 enter_timing = time.time()
# --> 563 response_data = self.request(root,
#     564                              method,
#     565                              url,
#     566                              query_params=query_params,
#     567                              headers=headers,
#     568                              post_params=post_params,
#     569                              body=body,
#     570                              _preload_content=_preload_content,
#     571                              _request_timeout=_request_timeout)
#     573 if response_data.status != 202 or not self._enable_long_running_polling:
#     574     return response_data
#
# File /opt/conda/lib/python3.9/site-packages/snowflake/core/image_repository/_generated/api_client.py:626, in ApiClient.request(self, root, method, url, query_params, headers, post_params, body, _preload_content, _request_timeout)
#     624 """Makes the HTTP request using RESTClient."""
#     625 if method == "GET":
# --> 626     return self.rest_client.get_request(
#     627         root,
#     628         url,
#     629         query_params=query_params,
#     630         _preload_content=_preload_content,
#     631         _request_timeout=_request_timeout,
#     632         headers=headers,
#     633     )
#     634 elif method == "HEAD":
#     635     return self.rest_client.head_request(
#     636         root,
#     637         url,
#    (...)
#     641         headers=headers,
#     642     )
#
# File /opt/conda/lib/python3.9/site-packages/snowflake/core/image_repository/_generated/rest.py:215, in RESTClientObject.get_request(self, root, url, headers, query_params, _preload_content, _request_timeout)
#     206 def get_request(
#     207     self,
#     208     root,
#    (...)
#     213     _request_timeout=None,
#     214 ):
# --> 215     return self.request(
#     216         root,
#     217         "GET",
#     218         url,
#     219         headers=headers,
#     220         _preload_content=_preload_content,
#     221         _request_timeout=_request_timeout,
#     222         query_params=query_params,
#     223     )
#
# File /opt/conda/lib/python3.9/site-packages/snowflake/core/image_repository/_generated/rest.py:202, in RESTClientObject.request(self, root, method, url, query_params, headers, body, post_params, _preload_content, _request_timeout)
#     199     if 500 <= r.status <= 599:
#     200         raise ServerError(http_resp=r)
# --> 202     raise APIError(http_resp=r)
#     204 return r
#
# APIError: (400)
# Reason: Bad Request
# HTTP response headers: HTTPHeaderDict({'Content-Type': 'application/json', 'Date': 'Mon, 22 Jul 2024 07:36:36 GMT', 'Strict-Transport-Security': 'max-age=31536000', 'X-Content-Type-Options': 'nosniff', 'X-Frame-Options': 'deny', 'X-Snowflake-Request-ID': '679a235b-af1d-4141-9120-6550da8af077', 'Content-Length': '284', 'Connection': 'keep-alive'})
# HTTP response body: {
#   "code" : "397009",
#   "message" : "failed to list images, please check your image repo url.request details: https://zqiseam-ltifosforscsaws.registry.snowflakecomputing.com/login 401 unauthorized",
#   "request_id" : "679a235b-af1d-4141-9120-6550da8af077",
#   "error_code" : "397009"
# }

# %%
print(dir(new_image_repo))
# Out:
# ['_ImageRepositoryModel__properties', '__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', '_from_model', '_to_model', 'created_on', 'database_name', 'from_dict', 'name', 'owner', 'owner_role_type', 'repository_url', 'schema_name', 'to_dict']

# %%
print(dir(new_image_repo.to_dict()))
# Out:
# ['__class__', '__class_getitem__', '__contains__', '__delattr__', '__delitem__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getitem__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__ior__', '__iter__', '__le__', '__len__', '__lt__', '__ne__', '__new__', '__or__', '__reduce__', '__reduce_ex__', '__repr__', '__reversed__', '__ror__', '__setattr__', '__setitem__', '__sizeof__', '__str__', '__subclasshook__', 'clear', 'copy', 'fromkeys', 'get', 'items', 'keys', 'pop', 'popitem', 'setdefault', 'update', 'values']

# %%
print(new_image_repo.to_dict())
# Out:
# {'name': 'INSIGHT_SPCS_REPOSITORY'}
