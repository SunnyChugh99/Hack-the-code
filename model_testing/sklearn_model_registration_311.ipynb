# %%
# pip install fosforml

# %% [markdown]
# ## Sklearn Models Registration

# %% [markdown]
# ### session creation

# %%
from fosforml.model_manager.snowflakesession import get_session
session = get_session()

# %% [markdown]
# ### modeling

# %% [markdown]
# #### Multiclass classification

# %%
from sklearn.ensemble._forest import RandomForestClassifier
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
import pandas as pd

m_dataset = load_iris() 
feature_names = m_dataset.feature_names
u_features = [col.replace(" ","_").replace("(","").replace(")","") for col in feature_names]
m_df = pd.DataFrame(m_dataset.data,columns=u_features)
m_df["Target"] = m_dataset.target


x_train,x_test,y_train,y_test = train_test_split(m_df.iloc[:,:-1],m_df['Target'])
model = RandomForestClassifier()
model.fit(x_train,y_train)

y_pred = pd.DataFrame(model.predict(x_test),columns=["Predicted"])

# %%
from fosforml import register_model
register_model(
  model_obj=model,
  session=session,
  x_train=x_train,
  y_train=y_train,
  x_test=x_test,
  y_test=y_test,
  y_pred=y_pred,
  dataset_name = "iris",
  dataset_source = "iris",
  name="SklearnMulitClassModel_3_11_5_dec_1",
  description="This is a test sklearn model",
  flavour="sklearn",
  model_type="classification",
  conda_dependencies=["scikit-learn==1.3.2"],
  source="NOTEBOOK"
)
# Out:
# Calculating build time metrics
#
# Progress: ██████████████                                                         20.0%
# Calculating build time metrics
#
# Progress: ████████████████████████████                                           40.0%
# The version of package 'scikit-learn' in the local environment is 1.3.2, which does not fit the criteria for the requirement 'scikit-learn<1.4'. Your UDF might not work when the package version is different between the server and your local environment.
# DataFrame.flatten() is deprecated since 0.7.0. Use `DataFrame.join_table_function()` instead.
# The version of package 'scikit-learn' in the local environment is 1.3.2, which does not fit the criteria for the requirement 'scikit-learn<1.4'. Your UDF might not work when the package version is different between the server and your local environment.
# The version of package 'scikit-learn' in the local environment is 1.3.2, which does not fit the criteria for the requirement 'scikit-learn<1.4'. Your UDF might not work when the package version is different between the server and your local environment.
# Calculating build time metrics
#
# Progress: ██████████████████████████████████████████                             60.0%
# Calculating build time metrics
#
# Progress: ████████████████████████████████████████████████████████               80.0%
# Calculating build time metrics
#
# Progress: ██████████████████████████████████████████████████████████████████████ 100.0%
# "Failed to save build time metrics for model 'MODEL_031DBA4D_7F94_40CA_A850_EA33E610521B_FDC_SKLEARNMULITCLASSMODEL_3_11_5_DEC_1'. list index out of range"

# %% [markdown]
# #### Binary Classfication

# %%
from sklearn.ensemble._forest import RandomForestClassifier
from sklearn.datasets import load_breast_cancer
from sklearn.model_selection import train_test_split
import pandas as pd

m_dataset = load_breast_cancer() 
feature_names = m_dataset.feature_names
u_features = [feature.replace(" ","_") for feature in feature_names]
m_df = pd.DataFrame(m_dataset.data,columns=u_features)
m_df["Target"] = m_dataset.target


x_train,x_test,y_train,y_test = train_test_split(m_df.iloc[:,:-1],m_df['Target'])
model = RandomForestClassifier()
model.fit(x_train,y_train)

y_pred = pd.DataFrame(model.predict(x_test),columns=["Predicted"])

# %%
from fosforml import register_model
register_model(
  model_obj=model,
  session=session,
  x_train=x_train,
  y_train=y_train,
  x_test=x_test,
  y_test=y_test,
  y_pred=y_pred,
  dataset_name = "iris",
  dataset_source = "iris",
  name="SklearnBinaryModel_3_11_5_dec",
  description="This is a test sklearn model",
  flavour="sklearn",
  model_type="classification",
  conda_dependencies=["scikit-learn==1.3.2"]
)
# Out:
# Calculating build time metrics
#
# Progress: ██████████████                                                         20.0%
# Calculating build time metrics
#
# Progress: ████████████████████████████                                           40.0%
# WARNING:snowflake.snowpark.session:The version of package 'scikit-learn' in the local environment is 1.3.2, which does not fit the criteria for the requirement 'scikit-learn<1.4'. Your UDF might not work when the package version is different between the server and your local environment.
# WARNING:snowflake.snowpark.session:The version of package 'scikit-learn' in the local environment is 1.3.2, which does not fit the criteria for the requirement 'scikit-learn<1.4'. Your UDF might not work when the package version is different between the server and your local environment.
# Calculating build time metrics
#
# Progress: ██████████████████████████████████████████                             60.0%
# WARNING:snowflake.snowpark.session:The version of package 'scikit-learn' in the local environment is 1.3.2, which does not fit the criteria for the requirement 'scikit-learn==1.3.*'. Your UDF might not work when the package version is different between the server and your local environment.
# WARNING:snowflake.snowpark.session:The version of package 'snowflake-snowpark-python' in the local environment is 1.25.0, which does not fit the criteria for the requirement 'snowflake-snowpark-python'. Your UDF might not work when the package version is different between the server and your local environment.
# WARNING:snowflake.snowpark.session:The version of package 'scikit-learn' in the local environment is 1.3.2, which does not fit the criteria for the requirement 'scikit-learn==1.3.*'. Your UDF might not work when the package version is different between the server and your local environment.
# WARNING:snowflake.snowpark.session:The version of package 'snowflake-snowpark-python' in the local environment is 1.25.0, which does not fit the criteria for the requirement 'snowflake-snowpark-python'. Your UDF might not work when the package version is different between the server and your local environment.
# Calculating build time metrics
#
# Progress: ████████████████████████████████████████████████████████               80.0%
# Calculating build time metrics
#
# Progress: ██████████████████████████████████████████████████████████████████████ 100.0%
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[5], line 2
#       1 from fosforml import register_model
# ----> 2 register_model(
#       3   model_obj=model,
#       4   session=session,
#       5   x_train=x_train,
#       6   y_train=y_train,
#       7   x_test=x_test,
#       8   y_test=y_test,
#       9   y_pred=y_pred,
#      10   dataset_name = "iris",
#      11   dataset_source = "iris",
#      12   name="SklearnBinaryModel_3_11_5_dec",
#      13   description="This is a test sklearn model",
#      14   flavour="sklearn",
#      15   model_type="classification",
#      16   conda_dependencies=["scikit-learn==1.3.2"]
#      17 )
#
# File /opt/conda/lib/python3.11/site-packages/fosforml/api.py:112, in register_model(model_obj, session, name, description, dataset_name, dataset_source, scoring_func, flavour, model_type, snowflake_df, conda_dependencies, x_train, y_train, x_test, y_test, y_pred, y_prob, prediction_column, target_column, metadata, source, connection_configs, **kwargs)
#     110 # register model
#     111 model_registry = ModelRegistry(session=session,connection_params=connection_configs)
# --> 112 reg_status,response = model_registry.register_model(
#     113     model=model_obj,
#     114     score=None,
#     115     model_name=model_name,
#     116     dataset_name=dataset_name,
#     117     dataset_source=dataset_source,
#     118     conda_dependencies=conda_dependencies,
#     119     description=description,
#     120     model_flavour=flavour,
#     121     model_type=model_type,
#     122     sf_input_dataframe=snowflake_df,
#     123     x_train=x_train,
#     124     y_train=y_train,
#     125     x_test=x_test,
#     126     y_test=y_test,
#     127     y_pred=y_pred,
#     128     prob=y_prob,
#     129     prediction_column=prediction_column,
#     130     target_column=target_column,
#     131     python_version=f"{sys.version_info.major}.{sys.version_info.minor}",
#     132     source=source,
#     133     metadata=metadata
#     134 )
#     136 return response
#
# File /opt/conda/lib/python3.11/site-packages/fosforml/model_manager/model_registry.py:81, in ModelRegistry.register_model(self, model, score, model_name, dataset_name, dataset_source, description, conda_dependencies, model_flavour, model_type, sf_input_dataframe, x_train, y_train, x_test, y_test, y_pred, prob, python_version, source, metadata, prediction_column, target_column)
#      78 metrics['flavour'] = model_flavour
#      79 metrics['model_type'] = model_type
# ---> 81 if source.upper() == "NOTEBOOK":
#      82     build_time_metrics = metrics.pop('model_metrics')
#      83     dataset_details = metrics.pop('dataset_details')
#
# AttributeError: 'NoneType' object has no attribute 'upper'

# %% [markdown]
# #### Regression

# %%
from sklearn.ensemble._forest import RandomForestRegressor
from sklearn.datasets import load_diabetes
from sklearn.model_selection import train_test_split
import pandas as pd

m_dataset = load_diabetes() 
feature_names = m_dataset.feature_names
u_features = [feature.replace(" ","_") for feature in feature_names]

m_df = pd.DataFrame(m_dataset.data,columns=u_features)
m_df["Target"] = m_dataset.target

x_train,x_test,y_train,y_test = train_test_split(m_df.iloc[:,:-1],m_df['Target'])
model = RandomForestRegressor()
model.fit(x_train,y_train)

y_pred = pd.DataFrame(model.predict(x_test),columns=["Predicted"])

# %%
from fosforml import register_model
register_model(
  name="SklearnRegressionModel_3_11_5_dec",
  model_obj=model,
  session=session,
  x_train=x_train,
  y_train=y_train,
  x_test=x_test,
  y_test=y_test,
  y_pred=y_pred,
  dataset_name = "iris",
  dataset_source = "iris",
  description="This is a test sklearn model",
  flavour="sklearn",
  model_type="regression",
  conda_dependencies=["scikit-learn==1.3.2"]
)
# Out:
# Calculating build time metrics
#
# Progress: ██████████████████                                                     25.0%
# WARNING:snowflake.snowpark.session:The version of package 'scikit-learn' in the local environment is 1.3.2, which does not fit the criteria for the requirement 'scikit-learn==1.3.*'. Your UDF might not work when the package version is different between the server and your local environment.
# WARNING:snowflake.snowpark.session:The version of package 'snowflake-snowpark-python' in the local environment is 1.25.0, which does not fit the criteria for the requirement 'snowflake-snowpark-python'. Your UDF might not work when the package version is different between the server and your local environment.
# Calculating build time metrics
#
# Progress: ███████████████████████████████████                                    50.0%
# Calculating build time metrics
#
# Progress: ████████████████████████████████████████████████████                   75.0%
# Calculating build time metrics
#
# Progress: ██████████████████████████████████████████████████████████████████████ 100.0%
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[7], line 2
#       1 from fosforml import register_model
# ----> 2 register_model(
#       3   name="SklearnRegressionModel_3_11_5_dec",
#       4   model_obj=model,
#       5   session=session,
#       6   x_train=x_train,
#       7   y_train=y_train,
#       8   x_test=x_test,
#       9   y_test=y_test,
#      10   y_pred=y_pred,
#      11   dataset_name = "iris",
#      12   dataset_source = "iris",
#      13   description="This is a test sklearn model",
#      14   flavour="sklearn",
#      15   model_type="regression",
#      16   conda_dependencies=["scikit-learn==1.3.2"]
#      17 )
#
# File /opt/conda/lib/python3.11/site-packages/fosforml/api.py:112, in register_model(model_obj, session, name, description, dataset_name, dataset_source, scoring_func, flavour, model_type, snowflake_df, conda_dependencies, x_train, y_train, x_test, y_test, y_pred, y_prob, prediction_column, target_column, metadata, source, connection_configs, **kwargs)
#     110 # register model
#     111 model_registry = ModelRegistry(session=session,connection_params=connection_configs)
# --> 112 reg_status,response = model_registry.register_model(
#     113     model=model_obj,
#     114     score=None,
#     115     model_name=model_name,
#     116     dataset_name=dataset_name,
#     117     dataset_source=dataset_source,
#     118     conda_dependencies=conda_dependencies,
#     119     description=description,
#     120     model_flavour=flavour,
#     121     model_type=model_type,
#     122     sf_input_dataframe=snowflake_df,
#     123     x_train=x_train,
#     124     y_train=y_train,
#     125     x_test=x_test,
#     126     y_test=y_test,
#     127     y_pred=y_pred,
#     128     prob=y_prob,
#     129     prediction_column=prediction_column,
#     130     target_column=target_column,
#     131     python_version=f"{sys.version_info.major}.{sys.version_info.minor}",
#     132     source=source,
#     133     metadata=metadata
#     134 )
#     136 return response
#
# File /opt/conda/lib/python3.11/site-packages/fosforml/model_manager/model_registry.py:81, in ModelRegistry.register_model(self, model, score, model_name, dataset_name, dataset_source, description, conda_dependencies, model_flavour, model_type, sf_input_dataframe, x_train, y_train, x_test, y_test, y_pred, prob, python_version, source, metadata, prediction_column, target_column)
#      78 metrics['flavour'] = model_flavour
#      79 metrics['model_type'] = model_type
# ---> 81 if source.upper() == "NOTEBOOK":
#      82     build_time_metrics = metrics.pop('model_metrics')
#      83     dataset_details = metrics.pop('dataset_details')
#
# AttributeError: 'NoneType' object has no attribute 'upper'
