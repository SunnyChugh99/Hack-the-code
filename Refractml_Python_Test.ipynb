# %%
# !pip install category-encoders==2.4.0 
# !pip install refractml==1.0.3
# Out:
# Collecting category-encoders==2.4.0
#   Downloading https://files.pythonhosted.org/packages/c6/8d/3e311afef42e48d226a78b376799507543a5339af8187d79f04d07015ba8/category_encoders-2.4.0-py2.py3-none-any.whl (86kB)
#      |████████████████████████████████| 92kB 12.6MB/s eta 0:00:01
# Collecting scipy>=1.0.0
#   Downloading https://files.pythonhosted.org/packages/35/f5/d0ad1a96f80962ba65e2ce1de6a1e59edecd1f0a7b55990ed208848012e0/scipy-1.13.1-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (38.6MB)
#      |████████████████████████████████| 38.6MB 39.3MB/s eta 0:00:01
# Collecting scikit-learn>=0.20.0
#   Downloading https://files.pythonhosted.org/packages/12/f8/d6bc56d20c60b2b66e005dfed16fdf8c46dbe559d40896d06c448a65f134/scikit_learn-1.5.1-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (13.4MB)
#      |████████████████████████████████| 13.4MB 76.0MB/s eta 0:00:01
# Collecting patsy>=0.5.1
#   Downloading https://files.pythonhosted.org/packages/43/f3/1d311a09c34f14f5973bb0bb0dc3a6e007e1eda90b5492d082689936ca51/patsy-0.5.6-py2.py3-none-any.whl (233kB)
#      |████████████████████████████████| 235kB 78.9MB/s eta 0:00:01
# Collecting numpy>=1.14.0
#   Downloading https://files.pythonhosted.org/packages/87/d3/74e627205462a170f39e7d7ddd2b4166a0d8ab163377592c7f4fa935cc8c/numpy-2.0.0-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (19.3MB)
#      |████████████████████████████████| 19.3MB 77.4MB/s eta 0:00:01
# Collecting pandas>=0.21.1
#   Downloading https://files.pythonhosted.org/packages/bb/30/f6f1f1ac36250f50c421b1b6af08c35e5a8b5a84385ef928625336b93e6f/pandas-2.2.2-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (13.1MB)
#      |████████████████████████████████| 13.1MB 79.9MB/s eta 0:00:01
# Collecting statsmodels>=0.9.0
#   Downloading https://files.pythonhosted.org/packages/e7/54/4c8086e90a54b8e57ac8ad63fc38eea20aa6507fb975efdb6c72210744c9/statsmodels-0.14.2-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (10.8MB)
#      |████████████████████████████████| 10.8MB 69.4MB/s eta 0:00:01
# Collecting joblib>=1.2.0
#   Downloading https://files.pythonhosted.org/packages/91/29/df4b9b42f2be0b623cbd5e2140cafcaa2bef0759a00b7b70104dcfe2fb51/joblib-1.4.2-py3-none-any.whl (301kB)
#      |████████████████████████████████| 307kB 78.9MB/s eta 0:00:01
# Collecting threadpoolctl>=3.1.0
#   Downloading https://files.pythonhosted.org/packages/4b/2c/ffbf7a134b9ab11a67b0cf0726453cedd9c5043a4fe7a35d1cefa9a1bcfb/threadpoolctl-3.5.0-py3-none-any.whl
# Collecting six
#   Downloading https://files.pythonhosted.org/packages/d9/5a/e7c31adbe875f2abbb91bd84cf2dc52d792b5a01506781dbcf25c91daf11/six-1.16.0-py2.py3-none-any.whl
# Collecting python-dateutil>=2.8.2
#   Downloading https://files.pythonhosted.org/packages/ec/57/56b9bcc3c9c6a792fcbaf139543cee77261f3651ca9da0c93f5c1221264b/python_dateutil-2.9.0.post0-py2.py3-none-any.whl (229kB)
#      |████████████████████████████████| 235kB 60.9MB/s eta 0:00:01
# Collecting pytz>=2020.1
#   Downloading https://files.pythonhosted.org/packages/9c/3d/a121f284241f08268b21359bd425f7d4825cffc5ac5cd0e1b3d82ffd2b10/pytz-2024.1-py2.py3-none-any.whl (505kB)
#      |████████████████████████████████| 512kB 69.4MB/s eta 0:00:01
# Collecting tzdata>=2022.7
#   Downloading https://files.pythonhosted.org/packages/65/58/f9c9e6be752e9fcb8b6a0ee9fb87e6e7a1f6bcab2cdc73f02bb7ba91ada0/tzdata-2024.1-py2.py3-none-any.whl (345kB)
#      |████████████████████████████████| 348kB 75.1MB/s eta 0:00:01
# Collecting packaging>=21.3
#   Downloading https://files.pythonhosted.org/packages/08/aa/cc0199a5f0ad350994d660967a8efb233fe0416e4639146c089643407ce6/packaging-24.1-py3-none-any.whl (53kB)
#      |████████████████████████████████| 61kB 12.8MB/s eta 0:00:01
# ERROR: openapi-schema-validator 0.6.2 has requirement jsonschema<5.0.0,>=4.19.1, but you'll have jsonschema 4.19.0 which is incompatible.
# ERROR: numba 0.58.1 has requirement numpy<1.27,>=1.22, but you'll have numpy 2.0.0 which is incompatible.
# ERROR: jupyterlab 3.2.4 has requirement jupyter-server~=1.4, but you'll have jupyter-server 2.7.3 which is incompatible.
# ERROR: contourpy 1.2.0 has requirement numpy<2.0,>=1.20, but you'll have numpy 2.0.0 which is incompatible.
# Installing collected packages: numpy, scipy, joblib, threadpoolctl, scikit-learn, six, patsy, python-dateutil, pytz, tzdata, pandas, packaging, statsmodels, category-encoders
# Successfully installed category-encoders-2.4.0 joblib-1.4.2 numpy-2.0.0 packaging-24.1 pandas-2.2.2 patsy-0.5.6 python-dateutil-2.9.0.post0 pytz-2024.1 scikit-learn-1.5.1 scipy-1.13.1 six-1.16.0 statsmodels-0.14.2 threadpoolctl-3.5.0 tzdata-2024.1
# WARNING: You are using pip version 19.3.1; however, version 24.1.2 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.
# Collecting refractml==1.0.3
#   Downloading https://files.pythonhosted.org/packages/f9/0d/023d845cf453feb632b08435c91f7e5d050c0df73c5be66bdbbca2f6ba87/refractml-1.0.3-py2.py3-none-any.whl (42kB)
#      |████████████████████████████████| 51kB 8.3MB/s  eta 0:00:01
# Collecting mosaic-utils
#   Downloading https://files.pythonhosted.org/packages/09/d7/8424b1dcaa5b1a2f824fc440aa1c4ef45e0bf6593d11b37962311614f365/mosaic_utils-1.0.2-py2.py3-none-any.whl (70kB)
#      |████████████████████████████████| 71kB 11.1MB/s eta 0:00:01
# Collecting shutils==0.1.0
#   Downloading https://files.pythonhosted.org/packages/46/1d/8c6017828045c2d510e2d1d480b563936be7755c97cff660afed947928b6/shutils-0.1.0.tar.gz
# Collecting urllib3==1.26.15
#   Downloading https://files.pythonhosted.org/packages/7b/f5/890a0baca17a61c1f92f72b81d3c31523c99bec609e60c292ea55b387ae8/urllib3-1.26.15-py2.py3-none-any.whl (140kB)
#      |████████████████████████████████| 143kB 64.9MB/s eta 0:00:01
# Collecting PyYAML==6.0
#   Downloading https://files.pythonhosted.org/packages/12/fc/a4d5a7554e0067677823f7265cb3ae22aed8a238560b5133b58cda252dad/PyYAML-6.0-cp39-cp39-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (661kB)
#      |████████████████████████████████| 665kB 84.4MB/s eta 0:00:01
# Collecting cloudpickle==1.6.0
#   Downloading https://files.pythonhosted.org/packages/e7/e3/898487e5dbeb612054cf2e0c188463acb358167fef749c53c8bb8918cea1/cloudpickle-1.6.0-py3-none-any.whl
# Collecting requests-toolbelt==0.9.1
#   Downloading https://files.pythonhosted.org/packages/60/ef/7681134338fc097acef8d9b2f8abe0458e4d87559c689a8c306d0957ece5/requests_toolbelt-0.9.1-py2.py3-none-any.whl (54kB)
#      |████████████████████████████████| 61kB 18.9MB/s eta 0:00:01
# Collecting scikit-learn==1.2.1; python_version >= "3.8"
#   Downloading https://files.pythonhosted.org/packages/de/5b/a3ee68c28dde18b9b744124c7e1701b8e5d588c8b0ef44d233864a97cffc/scikit_learn-1.2.1-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (9.6MB)
#      |████████████████████████████████| 9.6MB 75.6MB/s eta 0:00:01
# Collecting configparser
#   Downloading https://files.pythonhosted.org/packages/a8/20/f4aab9a42378542295c3be2bbdab353de10eb95396f6d4a5bc7a21b00952/configparser-7.0.0-py3-none-any.whl
# Collecting pymysql
#   Downloading https://files.pythonhosted.org/packages/0c/94/e4181a1f6286f545507528c78016e00065ea913276888db2262507693ce5/PyMySQL-1.1.1-py3-none-any.whl (44kB)
#      |████████████████████████████████| 51kB 16.4MB/s eta 0:00:01
# Collecting requests<3.0.0,>=2.0.1
#   Downloading https://files.pythonhosted.org/packages/f9/9b/335f9764261e915ed497fcdeb11df5dfd6f7bf257d4a6a2a686d80da4d54/requests-2.32.3-py3-none-any.whl (64kB)
#      |████████████████████████████████| 71kB 19.7MB/s eta 0:00:01
# Collecting numpy>=1.17.3
#   Using cached https://files.pythonhosted.org/packages/87/d3/74e627205462a170f39e7d7ddd2b4166a0d8ab163377592c7f4fa935cc8c/numpy-2.0.0-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl
# Collecting scipy>=1.3.2
#   Using cached https://files.pythonhosted.org/packages/35/f5/d0ad1a96f80962ba65e2ce1de6a1e59edecd1f0a7b55990ed208848012e0/scipy-1.13.1-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl
# Collecting threadpoolctl>=2.0.0
#   Using cached https://files.pythonhosted.org/packages/4b/2c/ffbf7a134b9ab11a67b0cf0726453cedd9c5043a4fe7a35d1cefa9a1bcfb/threadpoolctl-3.5.0-py3-none-any.whl
# Collecting joblib>=1.1.1
#   Using cached https://files.pythonhosted.org/packages/91/29/df4b9b42f2be0b623cbd5e2140cafcaa2bef0759a00b7b70104dcfe2fb51/joblib-1.4.2-py3-none-any.whl
# Collecting charset-normalizer<4,>=2
#   Downloading https://files.pythonhosted.org/packages/98/69/5d8751b4b670d623aa7a47bef061d69c279e9f922f6705147983aa76c3ce/charset_normalizer-3.3.2-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (142kB)
#      |████████████████████████████████| 143kB 77.4MB/s eta 0:00:01
# Collecting certifi>=2017.4.17
#   Downloading https://files.pythonhosted.org/packages/1c/d5/c84e1a17bf61d4df64ca866a1c9a913874b4e9bdc131ec689a0ad013fb36/certifi-2024.7.4-py3-none-any.whl (162kB)
#      |████████████████████████████████| 163kB 76.9MB/s eta 0:00:01
# Collecting idna<4,>=2.5
#   Downloading https://files.pythonhosted.org/packages/e5/3e/741d8c82801c347547f8a2a06aa57dbb1992be9e948df2ea0eda2c8b79e8/idna-3.7-py3-none-any.whl (66kB)
#      |████████████████████████████████| 71kB 19.2MB/s eta 0:00:01
# Building wheels for collected packages: shutils
#   Building wheel for shutils (setup.py) ... done
#   Created wheel for shutils: filename=shutils-0.1.0-cp39-none-any.whl size=3283 sha256=40088f4a2c2bedb22585f5fa44c70f5cf3fe73e38db4a1fa2b1593123578a52e
#   Stored in directory: /home/mosaic-ai/.cache/pip/wheels/ab/d0/0e/613976a1b51b5654859e2a82ade64329859bce431e280f2a39
# Successfully built shutils
# ERROR: numba 0.58.1 has requirement numpy<1.27,>=1.22, but you'll have numpy 2.0.0 which is incompatible.
# ERROR: mosaic-ai-client 1.0.0 has requirement matplotlib==3.1.1, but you'll have matplotlib 3.6.0 which is incompatible.
# ERROR: jsonschema-path 0.3.2 has requirement referencing<0.32.0,>=0.28.0, but you'll have referencing 0.33.0 which is incompatible.
# ERROR: contourpy 1.2.0 has requirement numpy<2.0,>=1.20, but you'll have numpy 2.0.0 which is incompatible.
# Installing collected packages: numpy, scipy, threadpoolctl, joblib, scikit-learn, mosaic-utils, configparser, pymysql, shutils, urllib3, PyYAML, cloudpickle, charset-normalizer, certifi, idna, requests, requests-toolbelt, refractml
# Successfully installed PyYAML-6.0 certifi-2024.7.4 charset-normalizer-3.3.2 cloudpickle-1.6.0 configparser-7.0.0 idna-3.7 joblib-1.4.2 mosaic-utils-1.0.2 numpy-2.0.0 pymysql-1.1.1 refractml-1.0.3 requests-2.32.3 requests-toolbelt-0.9.1 scikit-learn-1.2.1 scipy-1.13.1 shutils-0.1.0 threadpoolctl-3.5.0 urllib3-1.26.15
# WARNING: Target directory /tmp/pip_packages/numpy already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /tmp/pip_packages/numpy-2.0.0.dist-info already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /tmp/pip_packages/numpy.libs already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /tmp/pip_packages/scipy already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /tmp/pip_packages/scipy-1.13.1.dist-info already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /tmp/pip_packages/scipy.libs already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /tmp/pip_packages/threadpoolctl.py already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /tmp/pip_packages/threadpoolctl-3.5.0.dist-info already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /tmp/pip_packages/__pycache__ already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /tmp/pip_packages/joblib already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /tmp/pip_packages/joblib-1.4.2.dist-info already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /tmp/pip_packages/sklearn already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /tmp/pip_packages/scikit_learn.libs already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /tmp/pip_packages/bin already exists. Specify --upgrade to force replacement.
# WARNING: You are using pip version 19.3.1; however, version 24.1.2 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.

# %%
# !pip uninstall -y urllib3

# %%
# !pip install urllib3==1.26.15

# %%
# !pip show cloudpickle

# %%
import pandas as pd
import numpy as np
import category_encoders as ce
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
import requests
from refractml import *
from refractml.constants import MLModelFlavours
# Out:
# /opt/conda/lib/python3.9/site-packages/_distutils_hack/__init__.py:33: UserWarning: Setuptools is replacing distutils.
#   warnings.warn("Setuptools is replacing distutils.")

# %%
# !pip install pandas --target /packages/Python-3.8/23616da5-c36c-4994-8414-2a19942bd81a/3.8

# %%
import pandas as pd

# %%
cars = pd.read_csv("car_new (1) (1).csv")
cars
# Out:
#       buying_num  maintenance_num  doors_num  persons_num  lugboot_num  \
# 0              3                3          0            0            2
# 1              3                3          0            0            2
# 2              3                3          0            0            1
# 3              3                3          0            0            1
# 4              3                3          0            0            1
# ...          ...              ...        ...          ...          ...
# 1722           1                1          3            2            1
# 1723           1                1          3            2            1
# 1724           1                1          3            2            0
# 1725           1                1          3            2            0
# 1726           1                1          3            2            0
#
#       safety_num  class_num
# 0              2          2
# 1              0          2
# 2              1          2
# 3              2          2
# 4              0          2
# ...          ...        ...
# 1722           2          1
# 1723           0          3
# 1724           1          2
# 1725           2          1
# 1726           0          3
#
# [1727 rows x 7 columns]

# %%
Y = cars['class_num']
X = cars.drop (['class_num'], axis=1)
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.18, shuffle=True, random_state=25)
print (X_train.shape, X_test.shape, y_train.shape, y_test.shape)
# Out:
# (1416, 6) (311, 6) (1416,) (311,)

# %%
first_tree = DecisionTreeClassifier()
model=first_tree.fit(X_train, y_train)
model
# Out:
# DecisionTreeClassifier()

# %%
y_pred = model.predict(X_test)
first_tree.score(X_test, y_test)
y_prob = model.predict_proba(X_test)[:,1]

# %%
@scoring_func
def score(model, request):
    payload = request.json["payload"]
    data = pd.DataFrame(eval(payload))
    prediction = pd.Series(model.predict(data))
    return prediction.tolist()

# %%
req = requests.Request()
req.json = {"payload":X_train.head(1).to_json()}

sch = generate_schema(score,(model, req), X_train)
print(sch)
# Out:
# {'input': {'type': 'pd.core.frame.DataFrame', 'items': {'type': 'object', 'properties': {'buying_num': {'type': 'integer', 'format': 'int64'}, 'maintenance_num': {'type': 'integer', 'format': 'int64'}, 'doors_num': {'type': 'integer', 'format': 'int64'}, 'persons_num': {'type': 'integer', 'format': 'int64'}, 'lugboot_num': {'type': 'integer', 'format': 'int64'}, 'safety_num': {'type': 'integer', 'format': 'int64'}}}, 'example': [{'buying_num': 1, 'maintenance_num': 2, 'doors_num': 0, 'persons_num': 2, 'lugboot_num': 0, 'safety_num': 1}, {'buying_num': 3, 'maintenance_num': 2, 'doors_num': 2, 'persons_num': 2, 'lugboot_num': 2, 'safety_num': 2}]}, 'output': {'type': 'array', 'items': {'type': 'object'}, 'example': [2]}}

# %%
# !pip freeze | grep -i scikit
# Out:
# scikit-learn==1.5.1

# %%
register_model(model, 
               score, 
               name='CarEval_26JUNE', 
               description='car evaluation classification model using sklearn', 
               flavour=MLModelFlavours.sklearn,
               schema=sch,
               y_true=y_test, 
               y_pred=y_pred,
               y_train=y_train, 
               y_test=y_test,
               x_train=X_train, 
               x_test=X_test, 
               prob=y_prob,
               labels=[0,1], 
               init_script="pip install scikit-learn==1.5.1",
               model_type="classification",
               input_type="json", 
               explain_ai=True, 
               feature_names=list(X_train), 
               feature_ids=list(X_train),
               target_names=[0,1,2,3], 
               kyd=True, 
               kyd_score = False
              )
# Out:
# Calculating build time metrics
#
# Progress: ██████████████████████████████████████████████████████████████████████ 100.0%
# VBox(children=(HTML(value='<style>.grad_1{background: #2468a4;} .grad_2{ color:white; background: #2468a4;}</s…
